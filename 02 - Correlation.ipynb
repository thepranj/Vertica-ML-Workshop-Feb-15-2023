# %% [markdown]
# # Correlation & Dependancy

# %% [markdown]
# Finding links between the different variables is a very important task. The main purpose of Data Science is to find which variables will have an impact on the Business. Having these information will help us to understand the data and to take decisions.
#
# Besides, many Machine Learning Models are sensible to the number of variables and the link between the different variables. Finding variables correlations and dependancies is also a very important task to know which variables to use when dealing with Machine Learning algorithms.
#
# Let's use the Telco Churn dataset to understand how to find links between the different variables in VerticaPy.

# %%
from verticapy import *
vdf = vDataFrame("public.churn")
display(vdf)
# Out:
#        customerID    gender    SeniorCitizen    Partner    Dependents   \\
# 1      0014-BMAQU      Male                0       True         False   \\
# 2      0031-PVLZI    Female                0       True          True   \\
# 3      0057-QBUQH    Female                0      False          True   \\
# 4      0137-OCGAB    Female                0      False         False   \\
# 5      0139-IVFJG    Female                0       True         False   \\
# 6      0178-SZBHO      Male                0       True          True   \\
# 7      0208-BPQEJ    Female                0       True          True   \\
# 8      0219-YTZUE      Male                0       True          True   \\
# 9      0220-EBGCE      Male                0      False         False   \\
# 10     0229-LFJAF      Male                0      False         False   \\
# 11     0230-UBYPQ      Male                1       True         False   \\
# 12     0260-ZDLGK    Female                0      False          True   \\
# 13     0268-QKIWO    Female                0      False         False   \\
# 14     0269-XFESX      Male                0       True          True   \\
# 15     0306-JAELE      Male                0      False         False   \\
# 16     0319-QZTCO    Female                0       True          True   \\
# 17     0334-GDDSO      Male                1      False         False   \\
# 18     0334-ZFJSR    Female                0       True         False   \\
# 19     0374-FIUCA      Male                0       True         False   \\
# 20     0378-CJKPV    Female                0       True         False   \\
# 21     0394-YONDK      Male                0       True          True   \\
# 22     0401-WDBXM      Male                0       True          True   \\
# 23     0428-IKYCP      Male                0       True         False   \\
# 24     0432-CAJZV      Male                0      False         False   \\
# 25     0440-MOGPM    Female                0      False         False   \\
# 26     0459-SPZHJ      Male                0       True          True   \\
# 27     0471-ARVMX    Female                1       True         False   \\
# 28     0505-SPOOW    Female                0       True         False   \\
# 29     0516-OOHAR      Male                0       True          True   \\
# 30     0572-ZJKLT    Female                0       True          True   \\
# 31     0617-AQNWT    Female                0       True         False   \\
# 32     0617-FHSGK      Male                0      False          True   \\
# 33     0621-TSSMU      Male                0       True         False   \\
# 34     0621-TWIEM      Male                0      False         False   \\
# 35     0623-GDISB    Female                0      False         False   \\
# 36     0637-UBJRP      Male                0       True          True   \\
# 37     0661-KQHNK    Female                0       True          True   \\
# 38     0661-WCQNQ      Male                0       True         False   \\
# 39     0665-XHDJU      Male                0       True         False   \\
# 40     0670-KDOMA    Female                0      False         False   \\
# 41     0679-TDGAK      Male                0       True          True   \\
# 42     0690-SRQID      Male                0      False         False   \\
# 43     0699-NDKJM    Female                0       True         False   \\
# 44     0716-BQNDX      Male                1      False         False   \\
# 45     0719-SYFRB    Female                0      False         False   \\
# 46     0771-WLCLA    Female                0       True          True   \\
# 47     0774-RMNUW    Female                0       True          True   \\
# 48     0784-ZQJZX      Male                0      False          True   \\
# 49     0786-IVLAW    Female                1      False         False   \\
# 50     0787-LHDYT      Male                0      False         False   \\
# 51     0839-JTCUD    Female                0       True          True   \\
# 52     0853-NWIFK    Female                0      False         False   \\
# 53     0867-LDTTC      Male                0      False         False   \\
# 54     0867-MKZVY    Female                0       True         False   \\
# 55     0895-LNKRC      Male                0       True          True   \\
# 56     0917-EZOLA      Male                1       True         False   \\
# 57     0961-ZWLVI      Male                0      False          True   \\
# 58     0962-CQPWQ    Female                0       True          True   \\
# 59     0988-AADSA    Female                0       True          True   \\
# 60     0988-JRWWP    Female                0      False         False   \\
# 61     1074-AMIOH    Female                0       True          True   \\
# 62     1088-CNNKB      Male                0       True         False   \\
# 63     1089-HDMKP      Male                1      False          True   \\
# 64     1098-KFQEC    Female                0       True          True   \\
# 65     1121-QSIVB    Female                0      False          True   \\
# 66     1140-UKVZG    Female                0      False         False   \\
# 67     1153-GNOLC      Male                0      False         False   \\
# 68     1177-XZBJL      Male                0       True          True   \\
# 69     1200-TUZHR    Female                1      False         False   \\
# 70     1212-GLHMD      Male                0      False         False   \\
# 71     1213-NGCUN    Female                0      False         False   \\
# 72     1215-VFYVK    Female                0      False         False   \\
# 73     1265-HVPZB      Male                0       True         False   \\
# 74     1338-CECEE      Male                0       True          True   \\
# 75     1347-KTTTA      Male                0       True         False   \\
# 76     1360-JYXKQ    Female                1       True         False   \\
# 77     1371-OJCEK    Female                0      False         False   \\
# 78     1389-WNUIB    Female                0       True          True   \\
# 79     1395-OFUWC      Male                0       True          True   \\
# 80     1397-XKKWR      Male                0      False         False   \\
# 81     1431-AIDJQ      Male                0       True          True   \\
# 82     1439-LCGVL    Female                0       True         False   \\
# 83     1448-CYWKC    Female                0       True          True   \\
# 84     1455-UGQVH      Male                0       True         False   \\
# 85     1478-VPOAD    Female                0      False         False   \\
# 86     1488-PBLJN    Female                0       True          True   \\
# 87     1522-VVDMG      Male                0       True          True   \\
# 88     1548-ARAGG    Female                0       True          True   \\
# 89     1564-HJUVY      Male                0      False         False   \\
# 90     1576-PFZIW      Male                1       True         False   \\
# 91     1579-KLYDT      Male                0      False         False   \\
# 92     1585-MQSSU      Male                0      False         False   \\
# 93     1622-HSHSF    Female                0      False         False   \\
# 94     1624-WOIWJ    Female                0      False         False   \\
# 95     1658-XUHBX    Female                1       True          True   \\
# 96     1699-UOTXU      Male                0      False         False   \\
# 97     1707-HABPF    Female                1      False         False   \\
# 98     1741-WTPON      Male                0       True          True   \\
# 99     1752-OZXFY      Male                0       True         False   \\
# 100    1763-WQFUK      Male                0      False         False   \\
#        tenure    PhoneService       MultipleLines    InternetService   \\
# 1          63            True                 Yes        Fiber optic   \\
# 2           4            True                  No                 No   \\
# 3          43            True                 Yes                 No   \\
# 4           1            True                 Yes        Fiber optic   \\
# 5           2            True                  No        Fiber optic   \\
# 6          47            True                 Yes        Fiber optic   \\
# 7          12            True                  No                 No   \\
# 8           4            True                 Yes        Fiber optic   \\
# 9           2            True                  No        Fiber optic   \\
# 10         72            True                 Yes                DSL   \\
# 11         63           False    No phone service                DSL   \\
# 12          9            True                  No                DSL   \\
# 13          3            True                  No                 No   \\
# 14         23            True                 Yes                 No   \\
# 15          5            True                  No        Fiber optic   \\
# 16          3            True                  No                DSL   \\
# 17          3            True                 Yes        Fiber optic   \\
# 18         55            True                 Yes                DSL   \\
# 19         65            True                  No                 No   \\
# 20         72            True                 Yes        Fiber optic   \\
# 21         70            True                 Yes                 No   \\
# 22         72            True                 Yes        Fiber optic   \\
# 23         22            True                  No        Fiber optic   \\
# 24          3            True                  No        Fiber optic   \\
# 25         41            True                 Yes                DSL   \\
# 26         63            True                 Yes                DSL   \\
# 27         62            True                 Yes        Fiber optic   \\
# 28         70            True                  No                 No   \\
# 29         28            True                  No        Fiber optic   \\
# 30         46            True                 Yes        Fiber optic   \\
# 31         64           False    No phone service                DSL   \\
# 32         49            True                 Yes        Fiber optic   \\
# 33         56            True                  No                 No   \\
# 34         10            True                  No                DSL   \\
# 35          1            True                  No                DSL   \\
# 36         13            True                  No        Fiber optic   \\
# 37          6            True                  No                 No   \\
# 38         22            True                  No                DSL   \\
# 39         72            True                 Yes        Fiber optic   \\
# 40          1            True                  No                 No   \\
# 41         50            True                  No                DSL   \\
# 42          4            True                  No                 No   \\
# 43         57           False    No phone service                DSL   \\
# 44         57            True                 Yes        Fiber optic   \\
# 45         12            True                 Yes                DSL   \\
# 46         16            True                 Yes        Fiber optic   \\
# 47         71           False    No phone service                DSL   \\
# 48         72            True                  No                 No   \\
# 49         66            True                 Yes        Fiber optic   \\
# 50         16            True                  No                 No   \\
# 51         66            True                 Yes                DSL   \\
# 52         45            True                  No        Fiber optic   \\
# 53          5            True                  No                DSL   \\
# 54         20            True                 Yes        Fiber optic   \\
# 55          6            True                  No                 No   \\
# 56         72            True                 Yes        Fiber optic   \\
# 57         49            True                 Yes        Fiber optic   \\
# 58         62            True                  No                 No   \\
# 59         72            True                 Yes                DSL   \\
# 60          3            True                  No                DSL   \\
# 61         53            True                  No        Fiber optic   \\
# 62         63            True                 Yes                DSL   \\
# 63         11            True                  No                DSL   \\
# 64         55            True                  No                 No   \\
# 65         44            True                 Yes                DSL   \\
# 66         17            True                 Yes                 No   \\
# 67         33           False    No phone service                DSL   \\
# 68         53            True                 Yes                DSL   \\
# 69          8            True                 Yes        Fiber optic   \\
# 70          3            True                  No        Fiber optic   \\
# 71          6            True                  No                DSL   \\
# 72          4           False    No phone service                DSL   \\
# 73         59            True                  No                DSL   \\
# 74         41            True                 Yes                DSL   \\
# 75         64            True                  No        Fiber optic   \\
# 76         54            True                  No        Fiber optic   \\
# 77         48            True                 Yes                 No   \\
# 78         20            True                 Yes                DSL   \\
# 79         43           False    No phone service                DSL   \\
# 80          7           False    No phone service                DSL   \\
# 81         33            True                  No                DSL   \\
# 82         26            True                  No                 No   \\
# 83         58            True                 Yes        Fiber optic   \\
# 84         10            True                 Yes        Fiber optic   \\
# 85          1            True                  No                DSL   \\
# 86         72            True                 Yes        Fiber optic   \\
# 87          7            True                  No        Fiber optic   \\
# 88          4            True                 Yes                DSL   \\
# 89          4            True                  No                DSL   \\
# 90         70            True                  No        Fiber optic   \\
# 91          7            True                 Yes        Fiber optic   \\
# 92         17            True                  No                DSL   \\
# 93          1            True                  No                 No   \\
# 94         10            True                  No        Fiber optic   \\
# 95         59            True                 Yes        Fiber optic   \\
# 96         60            True                  No                DSL   \\
# 97         46            True                  No        Fiber optic   \\
# 98         56            True                 Yes        Fiber optic   \\
# 99         60            True                  No                DSL   \\
# 100         3            True                  No                DSL   \\
#             OnlineSecurity           OnlineBackup       DeviceProtection   \\
# 1                      Yes                     No                     No   \\
# 2      No internet service    No internet service    No internet service   \\
# 3      No internet service    No internet service    No internet service   \\
# 4                       No                    Yes                     No   \\
# 5                      Yes                    Yes                     No   \\
# 6                       No                    Yes                     No   \\
# 7      No internet service    No internet service    No internet service   \\
# 8                       No                    Yes                    Yes   \\
# 9                       No                     No                    Yes   \\
# 10                     Yes                    Yes                    Yes   \\
# 11                     Yes                     No                     No   \\
# 12                      No                     No                    Yes   \\
# 13     No internet service    No internet service    No internet service   \\
# 14     No internet service    No internet service    No internet service   \\
# 15                      No                     No                     No   \\
# 16                      No                    Yes                     No   \\
# 17                      No                    Yes                     No   \\
# 18                     Yes                    Yes                     No   \\
# 19     No internet service    No internet service    No internet service   \\
# 20                     Yes                    Yes                    Yes   \\
# 21     No internet service    No internet service    No internet service   \\
# 22                     Yes                     No                    Yes   \\
# 23                      No                     No                    Yes   \\
# 24                      No                     No                     No   \\
# 25                      No                    Yes                    Yes   \\
# 26                     Yes                    Yes                    Yes   \\
# 27                     Yes                     No                    Yes   \\
# 28     No internet service    No internet service    No internet service   \\
# 29                      No                    Yes                    Yes   \\
# 30                     Yes                     No                    Yes   \\
# 31                     Yes                     No                    Yes   \\
# 32                      No                     No                     No   \\
# 33     No internet service    No internet service    No internet service   \\
# 34                      No                     No                     No   \\
# 35                     Yes                     No                     No   \\
# 36                     Yes                     No                     No   \\
# 37     No internet service    No internet service    No internet service   \\
# 38                     Yes                     No                     No   \\
# 39                      No                    Yes                     No   \\
# 40     No internet service    No internet service    No internet service   \\
# 41                     Yes                     No                     No   \\
# 42     No internet service    No internet service    No internet service   \\
# 43                     Yes                    Yes                    Yes   \\
# 44                     Yes                     No                     No   \\
# 45                     Yes                     No                    Yes   \\
# 46                     Yes                     No                    Yes   \\
# 47                     Yes                    Yes                     No   \\
# 48     No internet service    No internet service    No internet service   \\
# 49                      No                    Yes                    Yes   \\
# 50     No internet service    No internet service    No internet service   \\
# 51                     Yes                    Yes                    Yes   \\
# 52                     Yes                    Yes                     No   \\
# 53                      No                     No                    Yes   \\
# 54                     Yes                     No                     No   \\
# 55     No internet service    No internet service    No internet service   \\
# 56                      No                    Yes                    Yes   \\
# 57                     Yes                    Yes                    Yes   \\
# 58     No internet service    No internet service    No internet service   \\
# 59                     Yes                    Yes                    Yes   \\
# 60                      No                     No                     No   \\
# 61                      No                    Yes                    Yes   \\
# 62                     Yes                    Yes                    Yes   \\
# 63                      No                    Yes                     No   \\
# 64     No internet service    No internet service    No internet service   \\
# 65                      No                    Yes                     No   \\
# 66     No internet service    No internet service    No internet service   \\
# 67                      No                    Yes                     No   \\
# 68                     Yes                    Yes                     No   \\
# 69                      No                     No                     No   \\
# 70                     Yes                     No                     No   \\
# 71                      No                     No                     No   \\
# 72                     Yes                     No                    Yes   \\
# 73                     Yes                    Yes                    Yes   \\
# 74                      No                    Yes                    Yes   \\
# 75                      No                    Yes                    Yes   \\
# 76                      No                     No                    Yes   \\
# 77     No internet service    No internet service    No internet service   \\
# 78                     Yes                     No                     No   \\
# 79                      No                    Yes                     No   \\
# 80                     Yes                     No                    Yes   \\
# 81                      No                    Yes                    Yes   \\
# 82     No internet service    No internet service    No internet service   \\
# 83                      No                    Yes                    Yes   \\
# 84                      No                     No                    Yes   \\
# 85                      No                     No                     No   \\
# 86                     Yes                    Yes                    Yes   \\
# 87                      No                    Yes                     No   \\
# 88                      No                    Yes                     No   \\
# 89                      No                    Yes                     No   \\
# 90                     Yes                    Yes                    Yes   \\
# 91                      No                     No                    Yes   \\
# 92                      No                     No                     No   \\
# 93     No internet service    No internet service    No internet service   \\
# 94                     Yes                     No                     No   \\
# 95                      No                     No                    Yes   \\
# 96                     Yes                    Yes                    Yes   \\
# 97                      No                    Yes                    Yes   \\
# 98                     Yes                    Yes                    Yes   \\
# 99                     Yes                     No                     No   \\
# 100                     No                     No                     No   \\
#                TechSupport            StreamingTV        StreamingMovies   \\
# 1                      Yes                     No                     No   \\
# 2      No internet service    No internet service    No internet service   \\
# 3      No internet service    No internet service    No internet service   \\
# 4                       No                     No                     No   \\
# 5                       No                    Yes                     No   \\
# 6                       No                    Yes                     No   \\
# 7      No internet service    No internet service    No internet service   \\
# 8                       No                     No                     No   \\
# 9                       No                     No                    Yes   \\
# 10                     Yes                     No                     No   \\
# 11                     Yes                     No                     No   \\
# 12                     Yes                    Yes                    Yes   \\
# 13     No internet service    No internet service    No internet service   \\
# 14     No internet service    No internet service    No internet service   \\
# 15                     Yes                    Yes                    Yes   \\
# 16                      No                    Yes                     No   \\
# 17                      No                     No                     No   \\
# 18                     Yes                     No                     No   \\
# 19     No internet service    No internet service    No internet service   \\
# 20                     Yes                    Yes                    Yes   \\
# 21     No internet service    No internet service    No internet service   \\
# 22                      No                    Yes                    Yes   \\
# 23                      No                    Yes                     No   \\
# 24                      No                    Yes                    Yes   \\
# 25                      No                    Yes                    Yes   \\
# 26                      No                    Yes                    Yes   \\
# 27                      No                    Yes                    Yes   \\
# 28     No internet service    No internet service    No internet service   \\
# 29                      No                    Yes                    Yes   \\
# 30                     Yes                     No                    Yes   \\
# 31                     Yes                     No                    Yes   \\
# 32                      No                     No                     No   \\
# 33     No internet service    No internet service    No internet service   \\
# 34                      No                     No                     No   \\
# 35                      No                     No                     No   \\
# 36                      No                     No                    Yes   \\
# 37     No internet service    No internet service    No internet service   \\
# 38                     Yes                     No                     No   \\
# 39                      No                    Yes                    Yes   \\
# 40     No internet service    No internet service    No internet service   \\
# 41                     Yes                    Yes                    Yes   \\
# 42     No internet service    No internet service    No internet service   \\
# 43                      No                    Yes                    Yes   \\
# 44                     Yes                     No                    Yes   \\
# 45                     Yes                     No                     No   \\
# 46                     Yes                    Yes                    Yes   \\
# 47                     Yes                    Yes                    Yes   \\
# 48     No internet service    No internet service    No internet service   \\
# 49                      No                    Yes                    Yes   \\
# 50     No internet service    No internet service    No internet service   \\
# 51                     Yes                    Yes                    Yes   \\
# 52                      No                    Yes                    Yes   \\
# 53                     Yes                    Yes                    Yes   \\
# 54                      No                     No                     No   \\
# 55     No internet service    No internet service    No internet service   \\
# 56                      No                    Yes                    Yes   \\
# 57                      No                    Yes                    Yes   \\
# 58     No internet service    No internet service    No internet service   \\
# 59                     Yes                     No                    Yes   \\
# 60                      No                    Yes                     No   \\
# 61                     Yes                    Yes                    Yes   \\
# 62                     Yes                     No                    Yes   \\
# 63                     Yes                     No                     No   \\
# 64     No internet service    No internet service    No internet service   \\
# 65                      No                    Yes                    Yes   \\
# 66     No internet service    No internet service    No internet service   \\
# 67                      No                    Yes                     No   \\
# 68                     Yes                     No                     No   \\
# 69                      No                     No                    Yes   \\
# 70                      No                     No                    Yes   \\
# 71                     Yes                     No                     No   \\
# 72                     Yes                     No                    Yes   \\
# 73                      No                    Yes                     No   \\
# 74                      No                    Yes                     No   \\
# 75                     Yes                    Yes                    Yes   \\
# 76                     Yes                    Yes                    Yes   \\
# 77     No internet service    No internet service    No internet service   \\
# 78                      No                    Yes                    Yes   \\
# 79                      No                     No                     No   \\
# 80                      No                     No                     No   \\
# 81                     Yes                    Yes                    Yes   \\
# 82     No internet service    No internet service    No internet service   \\
# 83                      No                    Yes                    Yes   \\
# 84                      No                    Yes                    Yes   \\
# 85                      No                     No                     No   \\
# 86                     Yes                    Yes                    Yes   \\
# 87                     Yes                    Yes                     No   \\
# 88                     Yes                     No                     No   \\
# 89                     Yes                    Yes                     No   \\
# 90                      No                    Yes                    Yes   \\
# 91                      No                    Yes                     No   \\
# 92                     Yes                     No                     No   \\
# 93     No internet service    No internet service    No internet service   \\
# 94                      No                    Yes                     No   \\
# 95                      No                     No                    Yes   \\
# 96                      No                     No                     No   \\
# 97                      No                    Yes                     No   \\
# 98                     Yes                    Yes                    Yes   \\
# 99                      No                    Yes                     No   \\
# 100                    Yes                     No                     No   \\
#              Contract    PaperlessBilling                PaymentMethod   \\
# 1            Two year                True      Credit card (automatic)   \\
# 2      Month-to-month               False                 Mailed check   \\
# 3            Two year                True             Electronic check   \\
# 4      Month-to-month                True                 Mailed check   \\
# 5      Month-to-month               False             Electronic check   \\
# 6      Month-to-month               False             Electronic check   \\
# 7      Month-to-month               False    Bank transfer (automatic)   \\
# 8      Month-to-month                True    Bank transfer (automatic)   \\
# 9      Month-to-month                True             Electronic check   \\
# 10           Two year               False    Bank transfer (automatic)   \\
# 11           One year               False    Bank transfer (automatic)   \\
# 12     Month-to-month                True                 Mailed check   \\
# 13     Month-to-month               False             Electronic check   \\
# 14           One year               False                 Mailed check   \\
# 15     Month-to-month                True             Electronic check   \\
# 16     Month-to-month                True      Credit card (automatic)   \\
# 17     Month-to-month                True             Electronic check   \\
# 18           One year                True      Credit card (automatic)   \\
# 19           Two year                True      Credit card (automatic)   \\
# 20           Two year               False      Credit card (automatic)   \\
# 21           Two year               False      Credit card (automatic)   \\
# 22           Two year                True    Bank transfer (automatic)   \\
# 23     Month-to-month                True    Bank transfer (automatic)   \\
# 24     Month-to-month               False                 Mailed check   \\
# 25           One year                True             Electronic check   \\
# 26           Two year               False      Credit card (automatic)   \\
# 27           One year                True             Electronic check   \\
# 28           Two year               False    Bank transfer (automatic)   \\
# 29           One year               False    Bank transfer (automatic)   \\
# 30           Two year               False                 Mailed check   \\
# 31           Two year               False             Electronic check   \\
# 32     Month-to-month               False      Credit card (automatic)   \\
# 33           One year               False      Credit card (automatic)   \\
# 34     Month-to-month                True             Electronic check   \\
# 35     Month-to-month                True    Bank transfer (automatic)   \\
# 36     Month-to-month               False             Electronic check   \\
# 37           One year               False      Credit card (automatic)   \\
# 38           One year                True      Credit card (automatic)   \\
# 39           Two year                True             Electronic check   \\
# 40     Month-to-month                True                 Mailed check   \\
# 41           One year               False             Electronic check   \\
# 42     Month-to-month                True                 Mailed check   \\
# 43     Month-to-month                True    Bank transfer (automatic)   \\
# 44           Two year               False             Electronic check   \\
# 45     Month-to-month                True                 Mailed check   \\
# 46     Month-to-month                True             Electronic check   \\
# 47           Two year               False    Bank transfer (automatic)   \\
# 48           Two year               False      Credit card (automatic)   \\
# 49           One year               False    Bank transfer (automatic)   \\
# 50     Month-to-month                True      Credit card (automatic)   \\
# 51           Two year               False      Credit card (automatic)   \\
# 52           One year                True             Electronic check   \\
# 53     Month-to-month               False    Bank transfer (automatic)   \\
# 54     Month-to-month               False             Electronic check   \\
# 55           One year               False                 Mailed check   \\
# 56           Two year                True    Bank transfer (automatic)   \\
# 57           One year                True      Credit card (automatic)   \\
# 58           Two year               False    Bank transfer (automatic)   \\
# 59           Two year               False    Bank transfer (automatic)   \\
# 60     Month-to-month                True             Electronic check   \\
# 61     Month-to-month                True    Bank transfer (automatic)   \\
# 62           One year               False      Credit card (automatic)   \\
# 63     Month-to-month                True             Electronic check   \\
# 64           Two year               False      Credit card (automatic)   \\
# 65           One year                True                 Mailed check   \\
# 66     Month-to-month               False                 Mailed check   \\
# 67           One year                True             Electronic check   \\
# 68           One year               False    Bank transfer (automatic)   \\
# 69     Month-to-month               False             Electronic check   \\
# 70     Month-to-month                True                 Mailed check   \\
# 71     Month-to-month                True    Bank transfer (automatic)   \\
# 72     Month-to-month               False                 Mailed check   \\
# 73           One year               False      Credit card (automatic)   \\
# 74           One year               False    Bank transfer (automatic)   \\
# 75           One year                True      Credit card (automatic)   \\
# 76           One year                True             Electronic check   \\
# 77           One year               False    Bank transfer (automatic)   \\
# 78           One year               False    Bank transfer (automatic)   \\
# 79     Month-to-month               False      Credit card (automatic)   \\
# 80           One year               False                 Mailed check   \\
# 81           Two year               False      Credit card (automatic)   \\
# 82           One year               False                 Mailed check   \\
# 83           One year                True      Credit card (automatic)   \\
# 84     Month-to-month                True             Electronic check   \\
# 85     Month-to-month               False             Electronic check   \\
# 86           Two year                True    Bank transfer (automatic)   \\
# 87     Month-to-month                True             Electronic check   \\
# 88     Month-to-month                True                 Mailed check   \\
# 89     Month-to-month                True    Bank transfer (automatic)   \\
# 90           Two year               False      Credit card (automatic)   \\
# 91     Month-to-month                True             Electronic check   \\
# 92     Month-to-month               False                 Mailed check   \\
# 93     Month-to-month                True                 Mailed check   \\
# 94     Month-to-month                True                 Mailed check   \\
# 95     Month-to-month                True      Credit card (automatic)   \\
# 96           Two year               False             Electronic check   \\
# 97           One year                True    Bank transfer (automatic)   \\
# 98           Two year               False                 Mailed check   \\
# 99           One year                True                 Mailed check   \\
# 100    Month-to-month                True                 Mailed check   \\
#        MonthlyCharges    TotalCharges    Churn
# 1               84.65          5377.8    False
# 2               20.35           76.35     True
# 3                25.1         1070.15    False
# 4                80.2            80.2     True
# 5               90.35           190.5    False
# 6                87.2         4017.45    False
# 7                19.4           198.1    False
# 8                84.8           371.9     True
# 9               85.85           167.3     True
# 10              69.65         4908.25    False
# 11               36.1          2298.9    False
# 12               72.9           651.4     True
# 13              19.75           58.85     True
# 14              24.35           538.5    False
# 15               96.1           453.4     True
# 16               58.7           168.6    False
# 17              81.35           233.7     True
# 18              66.05          3462.1    False
# 19               20.4         1414.45    False
# 20              112.1         7965.95    False
# 21              25.15         1790.15    False
# 22             105.55         7542.25    False
# 23               87.0         1850.65    False
# 24               90.7          237.65    False
# 25              80.55          3263.9    False
# 26               83.5          5435.0    False
# 27             104.85          6312.9    False
# 28               19.8         1397.65    False
# 29             100.35          2799.0    False
# 30              99.65          4630.2    False
# 31              47.85          3147.5     True
# 32               75.2          3678.3     True
# 33              19.95         1126.75    False
# 34              45.55           402.6     True
# 35              48.45           48.45    False
# 36              84.05          1095.3     True
# 37               19.0           105.5    False
# 38              56.25          1292.2    False
# 39               99.4          7285.7    False
# 40              20.25           20.25    False
# 41               75.5          4025.6    False
# 42              19.65           67.55    False
# 43              58.75         3437.45    False
# 44              93.75         5625.55    False
# 45              61.65          713.75     True
# 46             112.95         1882.55    False
# 47               59.7         4122.65    False
# 48               19.9         1529.65    False
# 49              108.1          7238.6    False
# 50               20.6          330.25    False
# 51               89.9         5958.85    False
# 52              100.3         4483.95    False
# 53              75.15          392.65    False
# 54               82.4         1592.35     True
# 55              19.45           113.5    False
# 56             104.15         7689.95     True
# 57              109.2         5290.45    False
# 58               20.3         1296.15    False
# 59              80.85         5824.75    False
# 60               54.2           140.4    False
# 61             108.25          5935.1    False
# 62               80.0          5040.2    False
# 63              54.55          601.25    False
# 64               19.4          1083.0    False
# 65              77.55          3471.1    False
# 66               24.8          475.25    False
# 67               39.1          1309.0    False
# 68              64.15         3491.55    False
# 69               85.2          695.75    False
# 70              86.05          244.85    False
# 71              49.65          267.35     True
# 72              48.25          202.25    False
# 73               66.4          3958.2    False
# 74               68.5         2839.95    False
# 75             102.45          6654.1    False
# 76               99.1          5437.1    False
# 77              24.35          1133.7    False
# 78               76.0         1588.75    False
# 79               29.3         1224.05    False
# 80               35.3           264.8    False
# 81               82.1          2603.1    False
# 82               19.2           459.6    False
# 83              105.2          6225.4    False
# 84               98.5         1037.75     True
# 85               43.8            43.8    False
# 86             116.85          8477.7    False
# 87              89.75           608.8     True
# 88               58.5          224.85    False
# 89              63.75           226.2    False
# 90             105.35          7511.9    False
# 91              90.45          593.45     True
# 92               51.5           900.5     True
# 93              19.55           19.55    False
# 94               84.7          832.05     True
# 95              88.75         5348.65    False
# 96               61.4         3638.25    False
# 97               91.3         4126.35    False
# 98             115.85          6567.9    False
# 99               59.8         3561.15    False
# 100              50.5          147.75    False
# Rows: 1-100 | Columns: 21

# %% [markdown]
# Pearson correlation help us to find linear links between the variables. Having a strong Pearson relationship means that the two input variables are linearly correlated. It is the most used correlation function.

# %%
vdf.corr(method = "pearson")
# Out:
#                             "SeniorCitizen"             "Partner"            "Dependents"   \\
# "SeniorCitizen"                         1.0    0.0164786575974139      -0.211185088493958   \\
# "Partner"                0.0164786575974139                   1.0       0.452676282929464   \\
# "Dependents"             -0.211185088493958     0.452676282929464                     1.0   \\
# "tenure"                 0.0165668776818093     0.379697461168293       0.159712331216918   \\
# "PhoneService"          0.00857640107927944     0.017705663223972    -0.00176167854468371   \\
# "PaperlessBilling"        0.156529559311173    -0.014876622287891      -0.111377229193644   \\
# "MonthlyCharges"          0.220173338576271    0.0968479362564749      -0.113890230021935   \\
# "TotalCharges"            0.102410605395331     0.319072363238568       0.064653249421773   \\
# "Churn"                   0.150889328176473    -0.150447544959177      -0.164221401579725   \\
#                                    "tenure"          "PhoneService"     "PaperlessBilling"   \\
# "SeniorCitizen"          0.0165668776818093     0.00857640107927944      0.156529559311173   \\
# "Partner"                 0.379697461168293       0.017705663223972     -0.014876622287891   \\
# "Dependents"              0.159712331216918    -0.00176167854468371     -0.111377229193644   \\
# "tenure"                                1.0     0.00844820673274375    0.00615248159827112   \\
# "PhoneService"          0.00844820673274375                     1.0     0.0165048057325697   \\
# "PaperlessBilling"      0.00615248159827112      0.0165048057325697                    1.0   \\
# "MonthlyCharges"          0.247899856286151       0.247397963214133      0.352149967795986   \\
# "TotalCharges"              0.8258804609332       0.113008260954736      0.157829782865907   \\
# "Churn"                  -0.352228670113078      0.0119419800290031      0.191825331666468   \\
#                           "MonthlyCharges"        "TotalCharges"               "Churn"
# "SeniorCitizen"          0.220173338576271     0.102410605395331     0.150889328176473
# "Partner"               0.0968479362564749     0.319072363238568    -0.150447544959177
# "Dependents"            -0.113890230021935     0.064653249421773    -0.164221401579725
# "tenure"                 0.247899856286151       0.8258804609332    -0.352228670113078
# "PhoneService"           0.247397963214133     0.113008260954736    0.0119419800290031
# "PaperlessBilling"       0.352149967795986     0.157829782865907     0.191825331666468
# "MonthlyCharges"                       1.0     0.651064803226201     0.193356422237847
# "TotalCharges"           0.651064803226201                   1.0    -0.199484083567564
# "Churn"                  0.193356422237847    -0.199484083567564                   1.0
# Rows: 1-9 | Columns: 10

# %% [markdown]
# We can notice that the tenure is well correlated to the Total Charges which makes sense.

# %%
vdf.scatter(["tenure", "TotalCharges"])
vdf.corr(["tenure", "TotalCharges"], method = "pearson")
# Out:
# 0.8258804609332

# %% [markdown]
# However, having a low Pearson relationship doesn't mean not being correlated. For example, let's compute the Pearson correlation between the tenure and the Total Charges to the power of 20.

# %%
vdf.eval(name = "TotalCharges^20", expr = "POWER(TotalCharges, 20)")
vdf.scatter(["tenure", "TotalCharges^20"])
vdf.corr(["tenure", "TotalCharges^20"], method = "pearson")
# Out:
# 0.224994408804537

# %% [markdown]
# We know that the tenure and the Total Charges are highly linearly correlated. However we can notice that the correlation between the tenure and the Total Charges to the power of 20 is not very high. Indeed, Pearson coefficient is not robust to monotonic relationship. Rank based correlations are. That's why sometimes using Spearman correlation is a more suitable choice.

# %% [markdown]
# Linear: Variables tend to move in same relative direction and same rate
#
# Monotonic: Variables move in same direction, but not same rate

# %%
vdf.corr(method = "spearman")
# Out:
#                             "SeniorCitizen"             "Partner"            "Dependents"   \\
# "SeniorCitizen"                         1.0    0.0164786575974139      -0.211185088493958   \\
# "Partner"                0.0164786575974139                   1.0       0.452676282929464   \\
# "Dependents"             -0.211185088493958     0.452676282929464                     1.0   \\
# "tenure"                 0.0190767898701152     0.384665710284119       0.164485741353804   \\
# "PhoneService"          0.00857640107927944     0.017705663223972    -0.00176167854468371   \\
# "PaperlessBilling"        0.156529559311173    -0.014876622287891      -0.111377229193644   \\
# "MonthlyCharges"          0.221092529102162     0.108410945895981      -0.107082725586711   \\
# "TotalCharges"            0.105795342303725     0.343930553215626      0.0866797760484616   \\
# "Churn"                   0.150889328176473    -0.150447544959177      -0.164221401579725   \\
# "TotalCharges^20"         0.105795342303725     0.343930553215626      0.0866797760484616   \\
#                                    "tenure"          "PhoneService"     "PaperlessBilling"   \\
# "SeniorCitizen"          0.0190767898701152     0.00857640107927944      0.156529559311173   \\
# "Partner"                 0.384665710284119       0.017705663223972     -0.014876622287891   \\
# "Dependents"              0.164485741353804    -0.00176167854468371     -0.111377229193644   \\
# "tenure"                                1.0     0.00815081986907184    0.00792876239476321   \\
# "PhoneService"          0.00815081986907184                     1.0     0.0165048057325697   \\
# "PaperlessBilling"      0.00792876239476321      0.0165048057325697                    1.0   \\
# "MonthlyCharges"          0.276342245223708       0.238826410230016      0.346158879381323   \\
# "TotalCharges"            0.883103368818293      0.0838048547856037      0.151669712799097   \\
# "Churn"                  -0.369620778763435      0.0119419800290031      0.191825331666468   \\
# "TotalCharges^20"         0.883103368818293      0.0838048547856037      0.151669712799097   \\
#                           "MonthlyCharges"        "TotalCharges"               "Churn"   \\
# "SeniorCitizen"          0.221092529102162     0.105795342303725     0.150889328176473   \\
# "Partner"                0.108410945895981     0.343930553215626    -0.150447544959177   \\
# "Dependents"            -0.107082725586711    0.0866797760484616    -0.164221401579725   \\
# "tenure"                 0.276342245223708     0.883103368818293    -0.369620778763435   \\
# "PhoneService"           0.238826410230016    0.0838048547856037    0.0119419800290031   \\
# "PaperlessBilling"       0.346158879381323     0.151669712799097     0.191825331666468   \\
# "MonthlyCharges"                       1.0     0.633958405301206     0.184839285783758   \\
# "TotalCharges"           0.633958405301206                   1.0    -0.233211018585104   \\
# "Churn"                  0.184839285783758    -0.233211018585104                   1.0   \\
# "TotalCharges^20"        0.633958405301206                   1.0    -0.233211018585104   \\
#                          "TotalCharges^20"
# "SeniorCitizen"          0.105795342303725
# "Partner"                0.343930553215626
# "Dependents"            0.0866797760484616
# "tenure"                 0.883103368818293
# "PhoneService"          0.0838048547856037
# "PaperlessBilling"       0.151669712799097
# "MonthlyCharges"         0.633958405301206
# "TotalCharges"                         1.0
# "Churn"                 -0.233211018585104
# "TotalCharges^20"                      1.0
# Rows: 1-10 | Columns: 11

# %% [markdown]
# Spearman coefficient determines the monotonic relationships between the variables.

# %%
vdf.corr(["tenure", "TotalCharges^20"], method = "spearman")
# Out:
# 0.883103368818293

# %% [markdown]
# We can notice that Spearman coefficient stays the same if one of the variable can be expressed using a monotonic function on the other. The same applies to Kendall coefficient.

# %%
vdf.corr(method = "kendall")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#                             "SeniorCitizen"             "Partner"            "Dependents"   \\
# "SeniorCitizen"                           1    0.0164786575974139      -0.211185088493958   \\
# "Partner"                0.0164786575974139                     1       0.452676282929464   \\
# "Dependents"             -0.211185088493958     0.452676282929464                       1   \\
# "tenure"                 0.0153154063543276     0.317713503646956       0.135506499930892   \\
# "PhoneService"          0.00857640107927944     0.017705663223972    -0.00176167854468371   \\
# "PaperlessBilling"        0.156529559311173    -0.014876622287891      -0.111377229193644   \\
# "MonthlyCharges"          0.180635949216048    0.0886260353369454     -0.0874394375642774   \\
# "TotalCharges"           0.0873571166085645     0.279358144937778      0.0674036111339054   \\
# "Churn"                   0.150889328176473    -0.150447544959177      -0.164221401579725   \\
# "TotalCharges^20"        0.0873571166085645     0.279358144937778      0.0674036111339054   \\
#                                    "tenure"          "PhoneService"    "PaperlessBilling"   \\
# "SeniorCitizen"          0.0153154063543276     0.00857640107927944     0.156529559311173   \\
# "Partner"                 0.317713503646956       0.017705663223972    -0.014876622287891   \\
# "Dependents"              0.135506499930892    -0.00176167854468371    -0.111377229193644   \\
# "tenure"                                  1     0.00700180312561143    0.0063514568219607   \\
# "PhoneService"          0.00700180312561143                       1    0.0165048057325697   \\
# "PaperlessBilling"       0.0063514568219607      0.0165048057325697                     1   \\
# "MonthlyCharges"          0.190564868116964       0.195862538105968      0.28271562697138   \\
# "TotalCharges"            0.731699318287362      0.0690761344143585      0.12528100183927   \\
# "Churn"                  -0.302965018211126      0.0119419800290031     0.191825331666468   \\
# "TotalCharges^20"         0.731699318287362      0.0690761344143585      0.12528100183927   \\
#                            "MonthlyCharges"        "TotalCharges"               "Churn"   \\
# "SeniorCitizen"           0.180635949216048    0.0873571166085645     0.150889328176473   \\
# "Partner"                0.0886260353369454     0.279358144937778    -0.150447544959177   \\
# "Dependents"            -0.0874394375642774    0.0674036111339054    -0.164221401579725   \\
# "tenure"                  0.190564868116964     0.731699318287362    -0.302965018211126   \\
# "PhoneService"            0.195862538105968    0.0690761344143585    0.0119419800290031   \\
# "PaperlessBilling"         0.28271562697138      0.12528100183927     0.191825331666468   \\
# "MonthlyCharges"                          1     0.458469198925234     0.150955285158245   \\
# "TotalCharges"            0.458469198925234                     1    -0.189101699239313   \\
# "Churn"                   0.150955285158245    -0.189101699239313                     1   \\
# "TotalCharges^20"         0.458469198925234     0.996878225678041    -0.189101699239313   \\
#                          "TotalCharges^20"
# "SeniorCitizen"         0.0873571166085645
# "Partner"                0.279358144937778
# "Dependents"            0.0674036111339054
# "tenure"                 0.731699318287362
# "PhoneService"          0.0690761344143585
# "PaperlessBilling"        0.12528100183927
# "MonthlyCharges"         0.458469198925234
# "TotalCharges"           0.996878225678041
# "Churn"                 -0.189101699239313
# "TotalCharges^20"                        1
# Rows: 1-10 | Columns: 11

# %% [markdown]
# We can notice that Kendall will also detect the monotonic relationship.

# %%
vdf.corr(["tenure", "TotalCharges^20"], method = "kendall")
# Out:
# 0.731699318287362

# %% [markdown]
# However Kendall is very expensive to compute. That's why most of the time, we will use Pearson and Spearman when dealing with numerical variables correlations.
#
# Binary features are considered as numerical but it is not truly the case. Correlation between a binary variable and a numerical variable can lead to false assumptions as binary variables can only takes two values which is hard to interpret in terms of order. That's why in this case, it is preferable to use the 'Biserial Point' method. It is a powerful method to understand the link between a binary variable and a numerical variable.

# %%
vdf.corr(method = "biserial")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#                             "SeniorCitizen"             "Partner"           "Dependents"   \\
# "SeniorCitizen"                           1    0.0164774876952011     -0.211170095409668   \\
# "Partner"                0.0164774876952011                     1      0.452644145179047   \\
# "Dependents"             -0.211170095409668     0.452644145179047                      1   \\
# "tenure"                 0.0165657015164121     0.379670504548958      0.159700992440771   \\
# "PhoneService"           0.0085757921977281     0.017704406210501    -0.0017615534743243   \\
# "PaperlessBilling"        0.156518446495901    -0.014875566122167     -0.111369321967821   \\
# "MonthlyCharges"          0.220157707371214      0.09684106053773     -0.113882144385631   \\
# "TotalCharges"            0.102403323381215     0.319049675261633     0.0646486521842783   \\
# "Churn"                   0.150878615789382    -0.150436863936483     -0.164209742682151   \\
# "TotalCharges^20"       0.00959483426594477    0.0945722425175577     0.0224428704447468   \\
#                                   "tenure"         "PhoneService"    "PaperlessBilling"   \\
# "SeniorCitizen"         0.0165657015164121     0.0085757921977281     0.156518446495901   \\
# "Partner"                0.379670504548958      0.017704406210501    -0.014875566122167   \\
# "Dependents"             0.159700992440771    -0.0017615534743243    -0.111369321967821   \\
# "tenure"                                 1                    nan                   nan   \\
# "PhoneService"                         nan                      1    0.0165036339739701   \\
# "PaperlessBilling"                     nan     0.0165036339739701                     1   \\
# "MonthlyCharges"                       nan      0.247380399196989     0.352124966910804   \\
# "TotalCharges"                         nan      0.113000225383144     0.157818560212722   \\
# "Churn"                                nan     0.0119411322081913     0.191811713028016   \\
# "TotalCharges^20"                      nan     0.0467146740346801    0.0579931118233683   \\
#                           "MonthlyCharges"        "TotalCharges"                "Churn"   \\
# "SeniorCitizen"          0.220157707371214     0.102403323381215      0.150878615789382   \\
# "Partner"                 0.09684106053773     0.319049675261633     -0.150436863936483   \\
# "Dependents"            -0.113882144385631    0.0646486521842783     -0.164209742682151   \\
# "tenure"                               nan                   nan                    nan   \\
# "PhoneService"           0.247380399196989     0.113000225383144     0.0119411322081913   \\
# "PaperlessBilling"       0.352124966910804     0.157818560212722      0.191811713028016   \\
# "MonthlyCharges"                         1                   nan      0.193342694899628   \\
# "TotalCharges"                         nan                     1     -0.199469899041392   \\
# "Churn"                  0.193342694899628    -0.199469899041392                      1   \\
# "TotalCharges^20"                      nan                   nan    -0.0630928693846116   \\
#                           "TotalCharges^20"
# "SeniorCitizen"         0.00959483426594477
# "Partner"                0.0945722425175577
# "Dependents"             0.0224428704447468
# "tenure"                                nan
# "PhoneService"           0.0467146740346801
# "PaperlessBilling"       0.0579931118233683
# "MonthlyCharges"                        nan
# "TotalCharges"                          nan
# "Churn"                 -0.0630928693846116
# "TotalCharges^20"                         1
# Rows: 1-10 | Columns: 11

# %% [markdown]
# The last important relationship is the one between categorical columns. In this case, the 'Cramer's V' method is very efficient. As there is no position in the Euclidian space for those variables, the 'Cramer's V' coefficients can not be negative (sign of an opposite relationship) and they will range in the interval [0;1].

# %%
vdf.corr(method = "cramer")

# %% [markdown]
# Sometimes, we just need to look at the correlation between a response and other variables. The parameter 'focus' will show us only the needed correlation vector.

# %%
vdf.corr(method = "cramer", focus = "Churn")

# %% [markdown]
# We can see that the Churn is correlated to the type of contract (Month-to-Month, Year-to-Year...) which makes sense as the different types of contracts can give more or less flexibility to the user to churn. The internet service seems also to be correlated to the churn. Let's split the different categories to binaries to understand which services can influence the global churning.

# %%
vdf["InternetService"].get_dummies()
vdf.corr(method = "spearman", 
         focus = "Churn", 
         columns = ["InternetService_DSL", 
                    "InternetService_Fiber_optic"])
# Out:
#                                    "Churn"
# "InternetService_Fiber_optic"        0.308
# "InternetService_DSL"               -0.124
# Rows: 1-2 | Columns: 2

# %% [markdown]
# We can notice that the Fiber Optic option seems to be directly linked to the customers churn. Let's compute some aggregations to understand where is the causality.

# %%
vdf["contract_month-to-month"].get_dummies()
vdf.groupby(["InternetService_Fiber_optic"], 
            ["AVG(tenure) AS tenure", 
             "AVG(totalcharges) AS totalcharges",
             'AVG("contract_month-to-month") AS "contract_month-to-month2"',
             'AVG("monthlycharges") AS "monthlycharges2"'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/verticapy/vdataframe.py:355, in vDataFrame.__getitem__(self, index)
#     354 try:
# --> 355     return getattr(self, new_index[0])
#     356 except:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 vdf["contract_month-to-month"].get_dummies()
#       2 vdf.groupby(["InternetService_Fiber_optic"],
#       3             ["AVG(tenure) AS tenure",
#       4              "AVG(totalcharges) AS totalcharges",
#       5              'AVG("contract_month-to-month") AS "contract_month-to-month2"',
#       6              'AVG("monthlycharges") AS "monthlycharges2"'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/verticapy/vdataframe.py:360, in vDataFrame.__getitem__(self, index)
#     358             return self.search(conditions=index)
#     359         else:
# --> 360             return getattr(self, index)
#     361 elif isinstance(index, Iterable):
#     362     try:
#
# AttributeError: 'vDataFrame' object has no attribute 'contract_month-to-month'

# %% [markdown]
# It seems that users having the Fiber Optic Options tend more to churn not because of the option itself but probably because of the type of contracts and the monthly charges the users are paying to get it. Be careful when dealing with correlation as finding correlation doesn't mean finding causations !
#
# Another important type of correlation is the auto-correlation. Let's use the Amazon dataset to understand it.

# %% [markdown]
# The main purpose is to predict the number of forest fires in Brazil. To do it, we can draw an Autocorrelation Plot and a Partial Autocorrelation Plot.

# %%
vdf = vDataFrame('public.amazon')

# %%
vdf
# Out:
#        number          date               state
# 1           0    1998-02-01            Amazonas
# 2           0    1998-02-01               Ceara
# 3           0    1998-04-01                 Rio
# 4           0    1998-04-01                 Rio
# 5           0    1998-04-01                 Rio
# 6           0    1998-04-01            Rondonia
# 7           0    1998-05-01                Piau
# 8           0    1998-06-01                 Rio
# 9           0    1998-07-01               Amapa
# 10          0    1998-08-01             Roraima
# 11          0    1999-03-01                Acre
# 12          0    1999-05-01             Roraima
# 13          0    1999-06-01                Acre
# 14          0    2000-03-01                 Rio
# 15          0    2000-05-01               Amapa
# 16          0    2000-06-01               Amapa
# 17          0    2000-07-01             Paraiba
# 18          0    2001-04-01                Para
# 19          0    2001-04-01             Paraiba
# 20          0    2001-04-01            Rondonia
# 21          0    2001-04-01             Sergipe
# 22          0    2001-05-01                Acre
# 23          0    2001-10-01    Distrito Federal
# 24          0    2003-02-01                Acre
# 25          0    2003-06-01             Sergipe
# 26          0    2004-01-01    Distrito Federal
# 27          0    2004-03-01    Distrito Federal
# 28          0    2004-08-01             Sergipe
# 29          0    2005-02-01                Acre
# 30          0    2005-07-01             Paraiba
# 31          0    2006-03-01               Amapa
# 32          0    2006-04-01                Acre
# 33          0    2006-06-01               Ceara
# 34          0    2007-05-01            Amazonas
# 35          0    2007-05-01             Sergipe
# 36          0    2008-05-01                 Rio
# 37          0    2008-05-01                 Rio
# 38          0    2008-06-01                 Rio
# 39          0    2008-07-01                 Rio
# 40          0    2008-12-01    Distrito Federal
# 41          0    2009-02-01               Amapa
# 42          0    2009-04-01                Acre
# 43          0    2009-05-01             Alagoas
# 44          0    2010-03-01    Distrito Federal
# 45          0    2011-05-01               Ceara
# 46          0    2014-02-01                Acre
# 47          0    2015-04-01               Amapa
# 48          1    1998-06-01          Pernambuco
# 49          1    1998-10-01             Roraima
# 50          1    1999-03-01           Tocantins
# 51          1    1999-11-01    Distrito Federal
# 52          1    2001-01-01      Espirito Santo
# 53          1    2001-06-01      Santa Catarina
# 54          1    2002-01-01             Sergipe
# 55          1    2002-07-01               Amapa
# 56          1    2003-05-01                 Rio
# 57          1    2005-05-01               Ceara
# 58          1    2005-05-01          Pernambuco
# 59          1    2005-05-01             Roraima
# 60          1    2007-03-01    Distrito Federal
# 61          1    2009-03-01               Amapa
# 62          1    2009-06-01          Pernambuco
# 63          1    2011-02-01    Distrito Federal
# 64          1    2011-04-01    Distrito Federal
# 65          1    2013-09-01             Sergipe
# 66          1    2016-02-01               Amapa
# 67          1    2016-05-01                 Rio
# 68          1    2017-08-01             Alagoas
# 69          2    2000-06-01      Santa Catarina
# 70          2    2001-04-01               Ceara
# 71          2    2004-02-01               Amapa
# 72          2    2005-04-01                 Rio
# 73          2    2006-04-01                 Rio
# 74          2    2008-03-01            Rondonia
# 75          2    2010-01-01               Amapa
# 76          2    2010-05-01               Amapa
# 77          2    2011-05-01               Amapa
# 78          2    2012-04-01               Ceara
# 79          2    2017-06-01             Alagoas
# 80          2    2017-06-01               Amapa
# 81          3    2000-01-01          Pernambuco
# 82          3    2001-01-01            Amazonas
# 83          3    2003-06-01            Amazonas
# 84          3    2004-02-01                Acre
# 85          3    2004-04-01                 Rio
# 86          3    2004-04-01                 Rio
# 87          3    2005-06-01          Pernambuco
# 88          3    2007-08-01             Alagoas
# 89          3    2009-05-01            Amazonas
# 90          3    2009-10-01    Distrito Federal
# 91          3    2010-05-01             Roraima
# 92          3    2011-12-01                 Rio
# 93          3    2013-12-01                Acre
# 94          4    1998-11-01      Espirito Santo
# 95          4    1999-04-01            Maranhao
# 96          4    2000-05-01                 Rio
# 97          4    2001-02-01             Alagoas
# 98          4    2001-05-01                 Rio
# 99          4    2001-05-01                 Rio
# 100         4    2001-11-01                 Rio
# Rows: 1-100 | Columns: 3

# %%
vdf.acf(column = "number",
        ts = "date",
        by = ["state"],
        p = 48,
        method = "pearson")
vdf.pacf(column = "number",
         ts = "date",
         by = ["state"],
         p = 48)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
#                           value              confidence
# 0                           1.0    0.024396841824873755
# 1             0.505342300215043    0.029989026236644414
# 2             0.211835049664936     0.03086934217616028
# 3           0.00639010239767066    0.030872522307420526
# 4           -0.0788715213261669     0.03099468035109108
# 5           -0.0403187010107322     0.03102830651534318
# 6           -0.0107361484426089     0.03103292535885791
# 7            0.0124626480737057     0.03103831386147466
# 8            0.0418920265165235     0.03107439584373587
# 9             0.119731380414743     0.03135055028483049
# 10            0.146747870994021    0.031759797722091095
# 11            0.225686565626742    0.032704399773641056
# 12            0.209265498633658     0.03349584265308683
# 13          -0.0460071464197358    0.033536106613121695
# 14           -0.142708164218292     0.03389898615587984
# 15          -0.0601015464921817    0.033965125435142365
# 16           -0.015151005845615     0.03397179533409799
# 17            0.013818168757464     0.03397778784448398
# 18           0.0576995066701112     0.03403885557963888
# 19           0.0656630452021953     0.03411702681770814
# 20           0.0657194506479771    0.034195172962428015
# 21            0.159838575017311    0.034641073642371886
# 22            0.227464720619891     0.03552454592486905
# 23            0.195021360317154     0.03616112343808141
# 24            0.328618034695463    0.037905967594490345
# 25            0.100370298413764     0.03806737386579177
# 26           -0.124407985025286     0.03831252186396724
# 27           0.0480969121056989     0.03835157210971187
# 28          -0.0450843454156458     0.03838622336916642
# 29           0.0150725131072097     0.03839274856770659
# 30           0.0031886220349721     0.03839589502714463
# 31         -0.00203869865815119     0.03839894858454655
# 32          -0.0205592422821393    0.038408521501236734
# 33          -0.0255421214888648     0.03842167211748339
# 34          -0.0249385099152871     0.03843434795440732
# 35           0.0340896542142763     0.03845543079649845
# 36            0.092692315094773     0.03859191370411651
# 37           0.0109743511348634    0.038596788611424314
# 38          -0.0550228757657708    0.038646728389823304
# 39           -0.017690152466675      0.0386545887811581
# 40         0.000634946161527453    0.038657608207935075
# 41           0.0355084793923624     0.03868015291792966
# 42          0.00954026551809549     0.03868457862452446
# 43          0.00316664782127113     0.03868775086328909
# 44           0.0165216382421956     0.03869499629970189
# 45           0.0126031056848333    0.038700475116278776
# 46           0.0617893644204225     0.03876258545493459
# 47           0.0922943035659485     0.03889713541475502
# 48            0.195250815881478     0.03948348134070975
# Rows: 1-49 | Columns: 3

# %% [markdown]
# We can see the seasonality of the process.

# %% [markdown]
# It is mathematically impossible to build the perfect correlation function. However, we can find many different links between the variables.
#
# Now we know how to explore our data. In the next chapter we will see how to enrich and build our final dataset using joins.
