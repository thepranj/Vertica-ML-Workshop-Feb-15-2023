# %% [markdown]
# # Amazon
#
# In this example, we VerticaPy with the 'Amazon' dataset to predict the number of forest fires in Brazil. You can download a copy of the Jupyter Notebook of the study <a href="amazon.ipynb">here</a>.
# <ul class="ul_content">
#     <li><b>date: </b>Date of the record</li>
#     <li><b>number: </b>Number of forest fires</li>
#     <li><b>state: </b>State in Brazil</li>
# </ul>
# We will follow the data science cycle (Data Exploration - Data Preparation - Data Modeling - Model Evaluation - Model Deployment) to solve this problem.
#
# ## Initialization
#
# Let's create a Virtual DataFrame of the dataset.

# %%
from verticapy import *
conn_info = {"host": "107.20.23.55", 
             "port": "5433", 
             "database": "testdrive", 
             "password": "password", 
             "user": "dbadmin"}
# Save a new connection
new_auto_connection(conn_info, name = "pranjs_cluster")
# Set the main auto connection
change_auto_connection("pranjs_cluster")

# %%
amazon = vDataFrame('amazon')

# %%
amazon
# Out:
#        number          date               state
# 1           0    1998-01-01               Goias
# 2           0    1998-01-01             Paraiba
# 3           0    1998-01-01             Paraiba
# 4           0    1998-01-01                 Rio
# 5           0    1998-01-01                 Rio
# 6           0    1998-01-01                 Rio
# 7           0    1998-01-01           Sao Paulo
# 8           0    1998-03-01               Bahia
# 9           0    1998-03-01               Goias
# 10          0    1998-03-01      Santa Catarina
# 11          0    1998-04-01                Para
# 12          0    1998-04-01          Pernambuco
# 13          0    1998-04-01           Tocantins
# 14          0    1998-05-01             Alagoas
# 15          0    1998-05-01            Amazonas
# 16          0    1998-05-01    Distrito Federal
# 17          0    1998-05-01             Roraima
# 18          0    1998-06-01               Amapa
# 19          0    1998-06-01             Sergipe
# 20          0    1998-11-01    Distrito Federal
# 21          0    1999-03-01    Distrito Federal
# 22          0    1999-06-01      Santa Catarina
# 23          0    2000-01-01    Distrito Federal
# 24          0    2000-02-01    Distrito Federal
# 25          0    2000-05-01      Santa Catarina
# 26          0    2000-07-01               Amapa
# 27          0    2000-09-01             Sergipe
# 28          0    2000-11-01                Acre
# 29          0    2001-01-01            Rondonia
# 30          0    2001-07-01             Alagoas
# 31          0    2001-07-01             Sergipe
# 32          0    2002-03-01    Distrito Federal
# 33          0    2003-06-01                Acre
# 34          0    2003-06-01             Alagoas
# 35          0    2003-08-01             Sergipe
# 36          0    2004-03-01               Amapa
# 37          0    2005-02-01    Distrito Federal
# 38          0    2005-05-01             Alagoas
# 39          0    2006-04-01            Rondonia
# 40          0    2006-05-01               Amapa
# 41          0    2006-06-01               Amapa
# 42          0    2006-06-01             Paraiba
# 43          0    2006-12-01                Acre
# 44          0    2007-04-01               Amapa
# 45          0    2007-05-01               Amapa
# 46          0    2007-06-01               Amapa
# 47          0    2008-04-01                 Rio
# 48          0    2008-05-01             Paraiba
# 49          0    2009-07-01                 Rio
# 50          0    2011-10-01    Distrito Federal
# 51          0    2014-08-01             Sergipe
# 52          0    2015-12-01    Distrito Federal
# 53          0    2017-07-01             Alagoas
# 54          1    1999-02-01            Rondonia
# 55          1    1999-05-01                 Rio
# 56          1    2002-03-01                 Rio
# 57          1    2002-12-01    Distrito Federal
# 58          1    2005-02-01      Espirito Santo
# 59          1    2005-04-01                Acre
# 60          1    2006-04-01                Piau
# 61          1    2008-08-01             Alagoas
# 62          1    2008-12-01      Espirito Santo
# 63          1    2009-04-01             Paraiba
# 64          1    2011-06-01                 Rio
# 65          1    2014-05-01             Sergipe
# 66          1    2016-03-01    Distrito Federal
# 67          1    2017-04-01                Acre
# 68          2    1999-02-01      Santa Catarina
# 69          2    1999-04-01          Pernambuco
# 70          2    2001-02-01          Pernambuco
# 71          2    2001-04-01          Pernambuco
# 72          2    2003-05-01            Amazonas
# 73          2    2003-06-01               Ceara
# 74          2    2003-08-01             Alagoas
# 75          2    2003-10-01             Sergipe
# 76          2    2006-04-01             Alagoas
# 77          2    2007-04-01      Santa Catarina
# 78          2    2013-04-01               Amapa
# 79          2    2013-05-01    Distrito Federal
# 80          3    1998-10-01    Distrito Federal
# 81          3    1999-06-01    Distrito Federal
# 82          3    1999-09-01             Roraima
# 83          3    1999-11-01             Sergipe
# 84          3    2000-04-01      Espirito Santo
# 85          3    2000-11-01      Espirito Santo
# 86          3    2003-02-01             Paraiba
# 87          3    2003-03-01               Ceara
# 88          3    2006-05-01    Distrito Federal
# 89          3    2008-03-01                 Rio
# 90          3    2010-06-01               Ceara
# 91          3    2012-07-01                 Rio
# 92          3    2014-06-01      Santa Catarina
# 93          3    2015-08-01             Alagoas
# 94          4    2001-03-01               Bahia
# 95          4    2004-05-01                 Rio
# 96          4    2006-08-01             Roraima
# 97          4    2007-04-01                 Rio
# 98          4    2008-01-01            Rondonia
# 99          4    2010-02-01    Distrito Federal
# 100         4    2011-08-01             Alagoas
# ...       ...           ...                 ...
# Rows: 1-100 of 6454 | Columns: 3

# %%
#read_csv('amazon.csv', schema = 'public', table_name = 'amazon')

# %% [markdown]
# ## Data Exploration and Preparation
#
# We can explore our data by displaying descriptive statistics of all the columns.

# %%
amazon.describe(method = "categorical")
# Out:
#                     dtype    count           top    top_percent
# "number"              int     6454             0           9.56
# "date"               date     6454    2017-01-01          0.434
# "state"       varchar(32)     6454           Rio         11.109
# Rows: 1-3 | Columns: 5

# %% [markdown]
# Data are available from 1998 to the end of 2017.

# %%
amazon["number"].describe()
# Out:
#                            value
# name                    "number"
# dtype                        int
# unique                    1472.0
# count                       6454
# mean            553.687325689495
# std             1592.64987447327
# min                          0.0
# approx_25%                   9.0
# approx_50%                  55.0
# approx_75%                 283.0
# max                      25963.0
# Rows: 1-11 | Columns: 2

# %% [markdown]
# Brazil has dry and rainy seasons, so the number of forest fires should vary by season. Let's confirm this using an autocorrelation plot with 48 lags (4 years).

# %%
# %matplotlib inline
amazon.acf(column = "number", 
           ts = "date",
           by = ["state"],
           p = 48)
# Out:
#             value              confidence
# 0             1.0    0.024396841824873755
# 1           0.531     0.03304773812790809
# 2           0.352    0.037823405347589246
# 3            0.21    0.042031387630226874
# 4           0.079     0.04562464810393294
# 5           0.021     0.04866179982410025
# 6          -0.031    0.051453460445325866
# 7          -0.019     0.05358451912221112
# 8           0.018     0.05557933150581347
# 9           0.084     0.05689678494526535
# 10          0.183     0.05808575515028097
# 11          0.332     0.05921076403140296
# 12          0.433     0.06028902578652599
# 13          0.338     0.06133594779648774
# 14           0.18      0.0623531795374632
# 15          0.076     0.06331212178432609
# 16            0.0     0.06403603274701192
# 17         -0.039     0.06445065035817167
# 18         -0.033     0.06483988336654478
# 19          0.003     0.06515249202986463
# 20           0.06     0.06545706439062442
# 21          0.181     0.06575704194665695
# 22          0.328      0.0660302841602363
# 23          0.514     0.06629023107298983
# 24          0.646     0.06654027414800838
# 25          0.484     0.06660877558603258
# 26          0.277     0.06667573112793855
# 27          0.204     0.06673683696014558
# 28          0.057     0.06679650081943712
# 29          0.013     0.06685337548919876
# 30         -0.031     0.06689406815128375
# 31         -0.022     0.06693145154601807
# 32          0.003     0.06696569046735545
# 33          0.083     0.06698819730270042
# 34          0.172     0.06700699782840724
# 35          0.324      0.0670219416391913
# 36          0.427     0.06703574390539116
# 37          0.326     0.06704954763082367
# 38          0.165     0.06705991550879374
# 39          0.078     0.06706946360595492
# 40         -0.006     0.06707862939224409
# 41         -0.024     0.06708708247914981
# 42         -0.044      0.0670952067586955
# 43          0.015     0.06710244856400374
# 44          0.063     0.06710919176348507
# 45          0.168     0.06711474861017658
# 46          0.317     0.06712006558260376
# 47           0.49     0.06712538379341723
# 48          0.533     0.06713062284777006
# Rows: 1-49 | Columns: 3

# %% [markdown]
# The effects of each season seem pretty clear. We can see this graphically using the cumulative sum of the number of forest fires partitioned by states. If our hypothesis is correct, we should see staircase functions.

# %%
amazon.cumsum("number", 
              by = ["state"], 
              order_by = ["date"], 
              name = "cum_sum")
amazon["cum_sum"].plot(ts = "date", 
                       by = "state")
# Out:
# <AxesSubplot:xlabel='"date"', ylabel='"cum_sum"'>

# %% [markdown]
# We can clearly see the seasonality per state which leads to a global seasonality. Let's draw the cumulative sum to see more clearly the phenomenon.

# %%
import verticapy.stats as st
amazon = amazon.groupby(["date"], 
                        [st.sum(amazon["number"])._as("number")])
amazon.cumsum("number", 
              order_by = ["date"], 
              name = "cum_sum")
amazon["cum_sum"].plot(ts = "date")
# Out:
# <AxesSubplot:xlabel='"date"', ylabel='"cum_sum"'>

# %% [markdown]
# Let's create an SAR(p) model to predict the number of forest fires in Brazil.

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# Let's create an AR model to predict the number of forest fires in Brazil. We know that this seasonality happens each year (s=12) and let's consider 4 lags (P=4).

# %%
from verticapy.learn.tsa import SARIMAX

model = SARIMAX("amazon_ar", 
                s = 12, 
                P = 4)
model.drop()
model.fit(amazon,
          y = "number",
          ts = "date")
model.regression_report()
# Out:
# /Users/vertica/opt/anaconda3/lib/python3.9/site-packages/verticapy/toolbox.py:571: Warning: The VerticaPy schema doesn't exist or is incomplete. The model can not be stored.
# Please use create_verticapy_schema function to set up the schema and the drop function to drop it if it is corrupted.
#   warnings.warn(warning_message, Warning)
#                                              value
# explained_variance               0.760622453388104
# max_error                    51895.523525632605339
# median_absolute_error             2282.16597852541
# mean_absolute_error               5698.57886703884
# mean_squared_error                96698237.9642302
# root_mean_squared_error          9833.526222278058
# r2                               0.760622453388105
# r2_adj                          0.7554745491598922
# aic                              3522.261520393983
# bic                              3538.198563209892
# Rows: 1-10 | Columns: 2

# %% [markdown]
# Our model is quite good. Let's look at our predictions.

# %%
x = model.plot(amazon, 
               nlead=960, 
               dynamic=True)

# %% [markdown]
# We can clearly see that our model caught the seasonality. Let's add the prediction in the vDataFrame.

# %%
amazon = model.predict(amazon, name = "prediction")
display(amazon)
# Out:
#              date    cum_sum            prediction    number
# 1      1998-01-01          0                  None         0
# 2      1998-02-01          0                  None         0
# 3      1998-03-01          0                  None         0
# 4      1998-04-01          0                  None         0
# 5      1998-05-01          0                  None         0
# 6      1998-06-01       3551                  None      3551
# 7      1998-07-01      11617                  None      8066
# 8      1998-08-01      47166                  None     35549
# 9      1998-09-01      89134                  None     41968
# 10     1998-10-01     112629                  None     23495
# 11     1998-11-01     119433                  None      6804
# 12     1998-12-01     123881                  None      4448
# 13     1999-01-01     124962                  None      1081
# 14     1999-02-01     126246                  None      1284
# 15     1999-03-01     126913                  None       667
# 16     1999-04-01     127630                  None       717
# 17     1999-05-01     129442                  None      1812
# 18     1999-06-01     133074                  None      3632
# 19     1999-07-01     141830                  None      8756
# 20     1999-08-01     181316                  None     39486
# 21     1999-09-01     218229                  None     36913
# 22     1999-10-01     245241                  None     27012
# 23     1999-11-01     254101                  None      8860
# 24     1999-12-01     258477                  None      4376
# 25     2000-01-01     259255                  None       778
# 26     2000-02-01     259816                  None       561
# 27     2000-03-01     260664                  None       848
# 28     2000-04-01     261201                  None       537
# 29     2000-05-01     263298                  None      2097
# 30     2000-06-01     269573                  None      6275
# 31     2000-07-01     274312                  None      4739
# 32     2000-08-01     296514                  None     22202
# 33     2000-09-01     319805                  None     23291
# 34     2000-10-01     347141                  None     27336
# 35     2000-11-01     355540                  None      8399
# 36     2000-12-01     360005                  None      4465
# 37     2001-01-01     360552                  None       547
# 38     2001-02-01     361611                  None      1059
# 39     2001-03-01     362879                  None      1268
# 40     2001-04-01     363960                  None      1081
# 41     2001-05-01     366050                  None      2090
# 42     2001-06-01     374483                  None      8433
# 43     2001-07-01     380973                  None      6490
# 44     2001-08-01     412860                  None     31887
# 45     2001-09-01     452694                  None     39834
# 46     2001-10-01     483732                  None     31038
# 47     2001-11-01     499371                  None     15639
# 48     2001-12-01     505572                  None      6201
# 49     2002-01-01     507226    2102.8752583153832      1654
# 50     2002-02-01     508796    2224.8632704867814      1570
# 51     2002-03-01     510475    2190.2598176482993      1679
# 52     2002-04-01     512157    2011.4943280845848      1682
# 53     2002-05-01     515975    3423.8314809038725      3818
# 54     2002-06-01     526814     7407.771725107113     10839
# 55     2002-07-01     540565     7470.848489237064     13751
# 56     2002-08-01     597716     30755.63031240348     57151
# 57     2002-09-01     653519     31808.00267002313     55803
# 58     2002-10-01     701241    29770.377887934286     47722
# 59     2002-11-01     729420    11983.892119729502     28179
# 60     2002-12-01     741364     6094.667771473334     11944
# 61     2003-01-01     746455     2070.472797675131      5091
# 62     2003-02-01     748853    2177.4990697936696      2398
# 63     2003-03-01     751602     2486.690117189002      2749
# 64     2003-04-01     754279     2280.767899190001      2677
# 65     2003-05-01     756026     3799.826032665235      1747
# 66     2003-06-01     762532    10057.371243870195      6506
# 67     2003-07-01     774336     8804.234330507625     11804
# 68     2003-08-01     818072       35645.173323258     43736
# 69     2003-09-01     880186     39637.69572760441     62114
# 70     2003-10-01     923481     35964.04804875412     43295
# 71     2003-11-01     947053    18506.897164811155     23572
# 72     2003-12-01     962395     8588.940440809427     15342
# 73     2004-01-01     965100     3521.953463947475      2705
# 74     2004-02-01     966355     2923.455880307091      1255
# 75     2004-03-01     968395     3116.302038167203      2040
# 76     2004-04-01     969730    3066.4073174217847      1335
# 77     2004-05-01     973265    3962.8403997795867      3535
# 78     2004-06-01     987527    10388.707959654532     14262
# 79     2004-07-01    1011336    12729.372336310704     23809
# 80     2004-08-01    1060661    49120.300669247306     49325
# 81     2004-09-01    1132416     56577.15917463745     71755
# 82     2004-10-01    1172747     43703.23126263032     40331
# 83     2004-11-01    1203510     25682.48397519586     30763
# 84     2004-12-01    1221034    12841.775153600236     17524
# 85     2005-01-01    1226024     4855.482069044121      4990
# 86     2005-02-01    1228177     3103.033864770306      2153
# 87     2005-03-01    1229883    3505.1039612962986      1706
# 88     2005-04-01    1230894    3293.1659785254137      1011
# 89     2005-05-01    1234104     4159.366841825614      3210
# 90     2005-06-01    1239915     11242.95084492932      5811
# 91     2005-07-01    1255578    17742.558956622306     15663
# 92     2005-08-01    1297146     52649.83843153255     41568
# 93     2005-09-01    1373403      66101.7671664849     76257
# 94     2005-10-01    1423279     46493.56621566262     49876
# 95     2005-11-01    1445031    29351.798143959182     21752
# 96     2005-12-01    1451385     16935.65966331975      6354
# 97     2006-01-01    1454640     5541.655676779425      3255
# 98     2006-02-01    1456306     3076.372191743811      1666
# 99     2006-03-01    1458080      3425.35774469751      1774
# 100    2006-04-01    1458872    2873.5463129696004       792
# Rows: 1-100 | Columns: 4

# %% [markdown]
# We can easily compare the prediction with the real value using a TS Plot.

# %%
amazon.plot(ts = "date", 
            columns = ["number", "prediction"])
# Out:
# <AxesSubplot:xlabel='"date"'>

# %% [markdown]
# Our prediction seems to follow the trend! We can also look at the distribution of the real values and the predictions.

# %%
amazon.boxplot(columns = ["number", "prediction"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Barring the really unpredictable events, our predictions seem to match up quite closely.

# %% [markdown]
# ## Conclusion
#
# We've solved our problem in a Pandas-like way, all without ever loading data into memory!
